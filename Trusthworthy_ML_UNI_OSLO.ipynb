# %% [markdown]
# <a href="https://colab.research.google.com/github/MrSimple07/Advanced-Machine-Learning-ITMO/blob/main/Trusthworthy_ML_UNI_OSLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 My motiv letter
#
# Dear Sir/Madam,
#
# I am writing to express my strong interest in the PhD Research Fellow position in Machine Learning at the Department of Informatics, Faculty of Mathematics and Natural Sciences at the University of Oslo. The proposed project on understanding the reliability of unsupervised machine learning methods in high-dimensional settings strongly aligns with my research interests in model evaluation, robustness, and trustworthy AI. In particular, the focus on benchmarking clustering workflows, exploring assumptions underlying unsupervised analysis, and developing systematic evaluation frameworks closely reflects the type of methodological research I aim to pursue during my doctoral studies.
#
# I hold a Master’s degree in Big Data and Machine Learning from ITMO University, graduating with honors (GPA 4.90/5.00). My academic training combines strong foundations in mathematics, statistics, and machine learning with practical experience in designing, evaluating, and deploying data-driven models. Throughout my studies and research projects, I have worked extensively with large datasets, model evaluation pipelines, and statistical analysis using Python-based machine learning frameworks.
#
# My research experience includes projects focused on model robustness, benchmarking, and systematic evaluation of machine learning systems. During my work as a Junior Machine Learning Engineer, I led the development of a benchmarking framework for evaluating large language models, introducing a novel robustness metric (“Model Stability”) that reduced performance variability across prompts by 30%. This work required designing evaluation datasets, implementing reproducible experiments, analysing model sensitivity to input perturbations, and interpreting results across multiple models. These experiences gave me practical insight into how model assumptions, evaluation procedures, and experimental design influence conclusions drawn from machine learning analyses.
#
# I have also conducted research internships at UiT – The Arctic University of Norway, where I developed time-series forecasting models for energy efficiency research, improving predictive performance by 35% through feature engineering and ensemble modelling techniques. This work involved analysing high-dimensional temporal datasets and designing predictive models for complex real-world systems. Later, at Rhine-Waal University of Applied Sciences, I worked as a research assistant in the Cloud Resilience Lab, contributing to a systematic research study on privacy in cloud systems. This role strengthened my research methodology skills, including literature synthesis, data analysis, and collaborative scientific writing.
#
# Simultaneously, in my current role as a Machine Learning Engineer at WEGOTRIP Inc., I design and deploy production-grade AI systems, including multi-source data integration pipelines and Retrieval-Augmented Generation (RAG) systems for personalised recommendations. I have also developed AI-powered educational tools serving more than 50,000 users, integrating multimodal data, large language model reasoning, and cloud deployment. These projects have strengthened my expertise in designing scalable machine learning systems and evaluating models under real-world constraints where robustness, interpretability, and reliability are critical.
#
# The research project at the Department of Informatics at the University of Oslo particularly resonates with me for several reasons:
#
# • Trustworthy unsupervised learning and robustness analysis — understanding when clustering results truly reflect underlying structure rather than artifacts is a fundamental challenge in machine learning, especially in high-dimensional settings.
#
# • Simulation-based benchmarking frameworks — developing controlled data-generating processes to systematically evaluate machine learning workflows aligns closely with my previous work on model benchmarking and stability evaluation.
#
# • Interdisciplinary scientific applications — applying machine learning methodology to challenging datasets from life sciences, such as gene expression and immune receptor repertoires, offers an exciting opportunity to contribute to impactful scientific research.
#
# I am particularly interested in contributing to the development of simulation-driven benchmarking frameworks that explore how clustering algorithms behave under varying data-generating assumptions, dimensionality levels, and structural complexity. Investigating stability-based validation methods, sensitivity to preprocessing choices, and robustness under realistic perturbations represents an important step toward making unsupervised learning more reliable for scientific discovery.
#
# I believe I am a strong candidate for this position because I combine:
#
# • A strong quantitative background in machine learning, statistical modelling, and data science.
#
# • Experience designing benchmarking and evaluation frameworks, including robustness metrics and reproducible experimental pipelines.
#
# • Practical expertise in Python-based machine learning workflows, large-scale data analysis, model evaluation, and reproducible research practices.
#
# Beyond my technical background, I am highly motivated to conduct rigorous methodological research that improves the reliability and interpretability of machine learning systems. The opportunity to join the SCML research group and contribute to the broader ecosystem of trustworthy AI research, including collaboration with TRUST – The Norwegian Centre for Trustworthy AI, represents an ideal environment to develop as a researcher and contribute to advancing the foundations of reliable machine learning.
#
# Thank you very much for considering my application. I would be honored to contribute to the research activities at the University of Oslo and to the development of robust and trustworthy machine learning methodologies.
#
# Sincerely,
# Muslimbek Abdurakhimov

# %% [markdown]
# # 2 Job description
#
# 🎓 PhD Fellowship in Trustworthy Machine Learning — University of Oslo, Norway
#
#
# Exciting fully funded PhD opportunity for anyone passionate about making unsupervised ML actually reliable.
#
# The project asks a deceptively hard question: *when can we trust clustering results?* In biology and life sciences, clustering drives real decisions — yet its assumptions almost never get stress-tested. This PhD builds the framework to fix that.
#
# You'll develop simulation-based benchmarks, probe failure modes of clustering pipelines, and apply causal reasoning to separate genuine data structure from noise and artifacts — all in high-dimensional biological settings like immune receptor repertoires and gene expression data.
#
# Supervision team:
# - 👩‍🔬 Dr. Milena Pavlović — Primary supervisor
#
# - 👨‍🏫 Prof. Anne-Marie George | Prof. Pooya Zakeri | Prof. Torbjørn Rogne — Co-supervisors
#
# What's on offer:
#
# 📍 Oslo, Norway
#
# 💰 NOK 550,800 – 595,000/year (fully funded)
#
# ⏳ 3-year fellowship (4th year possible)
#
# 🗓️ Start by October 1, 2026 | Deadline: March 24, 2026
#
#
# Unsupervised machine learning (ML) methods are widely used to explore structure in complex and high-dimensional data, particularly in the life sciences, where clustering analyses often form the basis for biological interpretation and hypothesis generation. In practice, the conclusions drawn from such analyses rest on a set of often implicit assumptions about what constitutes a meaningful or reliable result, for example, that stable solutions under realistic data perturbation are good indicators of the underlying structure, or that internal validation criteria capture the relevant aspects of the data and their representation. Many such assumptions are widely relied upon, yet rarely examined explicitly. In high-dimensional settings, these assumptions are especially difficult to justify, as sparsity and the curse of dimensionality make the identification and interpretation of the latent structure more challenging. This project addresses these challenges within the framework of trustworthy machine learning to clarify when unsupervised analyses, particularly clustering, can be meaningfully trusted to reflect properties of the underlying data-generating process.
# The central research challenge is to understand how clustering approaches and validation procedures behave as the data-generating process departs from idealized conditions and as dimensionality, heterogeneity, and structural complexity increase. The project will develop a simulation-based benchmarking framework that enables systematic exploration across controlled data-generating processes, explicitly designed to probe the assumptions underlying common unsupervised workflows. This exploration will include synthetic settings with known ground truth, as well as realistic and challenging use cases, such as adaptive immune receptor repertoires and gene expression data, which combine extremely high dimensionality, sparsity, and a strong need for biological interpretability. In such settings, current practice in applying clustering often falls short: multiple biologically plausible definitions of “true” clusters coexist, analyses typically rely on a single dataset and potentially misleading validation metrics, and robustness is seldom evaluated systematically (e.g., via stability assessments). By varying key properties of the data-generating process, the project will seek to identify not only characteristic failure modes of existing approaches, but also methodological patterns associated with more reliable structure discovery.
#
#
# The project adopts a unified and assumption-aware perspective on evaluation, emphasizing robustness analysis, sensitivity to modeling choices, and complementary empirical tests as essential components of trustworthy unsupervised learning in high-dimensional settings. Causality will be used as one analytical lens to assess when observed structure plausibly reflects underlying mechanisms rather than artifacts introduced by confounders or preprocessing choices. The resulting insights will inform practical guidance for model selection, validation, and workflow design, while more broadly contributing to a deeper understanding of what it means to trust unsupervised learning as an exploratory tool in scientific machine learning applications.
#
# The PhD position will be embedded in the SCML research group and contribute to its ongoing interdisciplinary work at the intersection of machine learning and life sciences. Dr. Milena Pavlović will serve as a primary supervisor for the project, with professors Anne-Marie George, Pooya Zakeri, and Torbjørn Rognes serving as co-supervisors. The candidate will collaborate with other PhD students and researchers in the group, particularly within existing life science projects. The position also offers opportunities for engagement with TRUST - The Norwegian Centre for Trustworthy AI, especially within the veridical AI research theme, fostering connections to broader interdisciplinary efforts in trustworthy and reliable AI and machine learning.

# %% [markdown]
# # 3.Introduction

# %% [markdown]
# # 4.Questions to ask
#
# 1. Integration & Collaboration
#
# - On the TRUST Centre: "How closely will this PhD interact with TRUST (The Norwegian Centre for Trustworthy AI)? I’m very interested in the 'Veridical AI' theme and would love to know if there are regular cross-disciplinary workshops there."
#
# - On Life Science Partnerships: "The project mentions collaboration with other researchers in life science projects. Will I be working directly with the biologists who generate the gene expression data to understand their 'biologically plausible' definitions of a cluster?"
#
#
# 2. Expectations & Success
#
# - On Methodology vs. Publication: "In the first year, is the priority more on conducting a systematic survey and benchmarking of existing unsupervised workflows, or is there a specific 'failure mode' in current methods that you are most anxious for this PhD to solve first?"
#
# - On the 4th Year Option: "The ad mentions a potential 4th year for career-promoting work like teaching or research assistance. How is that decision typically made, and are there specific teaching needs in the Department of Informatics that a candidate with my background could fill?"
#
# 3. Technical & Research-Focused
#
# - On Causality: "The advertisement mentions using causality as an analytical lens. Are you primarily interested in Causal Discovery—inferring the underlying network of gene interactions—or using Causal Inference to ensure that the clusters we find aren't just artifacts of batch effects or preprocessing choices?"
#
# - On Synthetic Data: "Since a major part of this project is a simulation-based benchmarking framework, what is the current 'gold standard' for ground truth in the group? Do you rely more on purely synthetic mathematical models or 'semi-synthetic' data derived from real biological repertoires?"
#
# - On High-Dimensionality: "Clustering in extremely high dimensions often leads to the 'distance concentration' problem. Is the group exploring manifold learning or specific dimensionality reduction techniques as a prerequisite for the stability assessments we want to build?"
